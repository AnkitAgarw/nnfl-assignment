# %%
# !unzip drive/'My Drive'/nnfl-assignment-2.zip
# Out:
# Archive:  drive/My Drive/nnfl-assignment-2.zip
#   inflating: final_test.csv
#   inflating: final_train.csv

# %%
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import pandas as pd
from keras.layers import  Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# !ls
# Out:
# drive  final_test.csv  final_train.csv	sample_data

# %%
test=pd.read_csv("./final_test.csv")
train=pd.read_csv("./final_train.csv")
print(train.head(5))
# Out:
#    class                                               desc  rating
# 0    173  "Humira gave me my life back.  I was sicker th...    10.0
# 1    533  "I&#039;m having a terrible time with the hysi...     1.0
# 2     95  "I have been on four different birth control p...    10.0
# 3    560  "Pain relief is limited and barely noticed. I ...     4.0
# 4    103  "Aside from the out of pocket cost ($130.00 fo...     9.0

# %%
x_train=train.drop(['rating'],axis=1)
x_class=[]
temp=np.array(train[['class']]).reshape(-1)
for i in temp:
#     print(i)
    a=np.zeros(836)
    a[i]=1
    x_class.append(a)
# print(min(np.array(train['class'])),max(np.array(train['class'])))
print(np.array(x_class).shape)
x_class=np.array(x_class)

y_train=train[['rating']]
train.info
# Out:
# (159523, 836)
# <bound method DataFrame.info of         class                                               desc  rating
# 0         173  "Humira gave me my life back.  I was sicker th...    10.0
# 1         533  "I&#039;m having a terrible time with the hysi...     1.0
# 2          95  "I have been on four different birth control p...    10.0
# 3         560  "Pain relief is limited and barely noticed. I ...     4.0
# 4         103  "Aside from the out of pocket cost ($130.00 fo...     9.0
# 5         204  "I love this medication  I have been taking it...    10.0
# 6         689  "I read several reviews about this drug and wa...    10.0
# 7         269  "Be careful when taking this medication. I too...     1.0
# 8           0  "Age 33 Male\r\r\nI have ADHD and High Functio...     8.0
# 9         422  "I originally started out on solely Prozac for...     8.0
# 10        381  "I started Travatan Z two weeks ago after pres...    10.0
# 11        334  "I&#039;ve suffered from excessive sweat under...     3.0
# 12         95  "This is my second month on this pill, about t...     7.0
# 13         95  "I have been taking Loestrin 24 for 3 months. ...     7.0
# 14         54  "I started Celexa 20mg about 2 months ago for ...    10.0
# 15        690  "Paxil has changed my life for the better. I a...    10.0
# 16        455  "soma helps my back pain effectively.I seem to...     9.0
# 17          4  "This is my first month on Loestrin.  I was pr...     5.0
# 18        103  "Yes it&#039;s effective, however, the taste i...     5.0
# 19         84  "Worked wonders, it was great to finally find ...     8.0
# 20         53  "I am Rxed this 6/day for neuropathy but on th...     3.0
# 21         53  "My experience of this medicine.. Only made me...     1.0
# 22        193  "I was on Cymbalta for about 3 months.  I can&...     1.0
# 23        533  "I have taken 4 of these pills. The first one ...     3.0
# 24        204  "I am on 2.4mg. The egg burps and diarrhea are...     8.0
# 25         95  "I&#039;ve been freaking out recently, because...     1.0
# 26         26  "I started Rogaine and Propecia about a year a...     8.0
# 27        319  "Fall 2015 noticed b/p was staying in the 140/...     5.0
# 28        757                       "Helps in-between flareups."     8.0
# 29        442  "I was prescribed this medicine for frequent m...     8.0
# ...       ...                                                ...     ...
# 159493     95  "I&#039;m reading a lot of bad reviews on here...     9.0
# 159494    621  "Controlled itchiness but did little to reduce...     5.0
# 159495    319  "I first stumbled upon this medication while l...    10.0
# 159496    234  "I took Ella One approximately 8-9 hours after...    10.0
# 159497     54  "Good stuff, the committee in my head has gone...    10.0
# 159498     53  "I take as needed .5mg, more if needed. Works ...    10.0
# 159499    475  "I&#039;ve been given Zofran pre op and post o...    10.0
# 159500     95  "I had the paragard inserted around May 2015 a...     5.0
# 159501     95  "I was on cyclessa no problems, until my Dr. S...     1.0
# 159502    372  "My 5 year old son was diagnosed yesterday wit...    10.0
# 159503    170  "I thought it helped a lot, not a miracle or a...     8.0
# 159504      0  "I am a 24 year old male with ADHD, high funct...     8.0
# 159505    193  "This medicine is wonderful.  I never believed...    10.0
# 159506    467  "Hopefully my experience will give some with N...    10.0
# 159507    811  "I was diagnosed with fibromyalgia ten years a...    10.0
# 159508     54  "Initially, my doctor started me out on 20mg, ...    10.0
# 159509    537  "I have suffered with Panic Attacks all my lif...    10.0
# 159510    148  "I have had quite remarkable relief of severe ...     9.0
# 159511     95  "My Personal Experience.\r\n  *   Effectivenes...     7.0
# 159512     95  "I just went to my doctor and had my second Mi...    10.0
# 159513    193  "Pristiq has helped me more than any other ant...     9.0
# 159514     53  "I am a 70 yr old woman &amp; have had anxiety...    10.0
# 159515     54  "I started taking this medicine when I was 24 ...    10.0
# 159516     95  "I switched to this pill because I was on Spri...     5.0
# 159517     90  "I have been taking Cardura for 15 years along...     2.0
# 159518    354  "I&#039;m 33 years old and have no reason to b...     7.0
# 159519     95  "My periods are shorter and I&#039;m regular. ...     8.0
# 159520    103  "Drinking this is what comes to mind if someon...     3.0
# 159521    622  "I was diagnosed with psoriatic arthritis in m...    10.0
# 159522    334  "My family has a history of perspiration probl...    10.0
#
# [159523 rows x 3 columns]>

# %%
x_test=test
y_train=np.array(y_train).reshape((-1))
print(y_train)
y_train=np.array(y_train)
# Out:
# [10.  1. 10. ...  3. 10. 10.]

# %%
print(y_train/10)
y_train=y_train/10
# Out:
# [1.  0.1 1.  ... 0.3 1.  1. ]

# %%
import numpy as np 
import pandas as pd 
import os

from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Model
from keras.layers import Dense, Embedding, LSTM, Input
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
import re

# %%
num_words = 100000
tokenizer = Tokenizer(num_words=num_words, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',lower=True,split=' ')
tokenizer.fit_on_texts(x_train['desc'].values)
X = tokenizer.texts_to_sequences(x_train['desc'].values)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

max_length_of_text = 200
X = pad_sequences(X, maxlen=max_length_of_text)

print(word_index)
# Out:
# Found 51286 unique tokens.
# {'i': 1, 'and': 2, 'the': 3, 'to': 4, 'it': 5, 'my': 6, 'a': 7, '039': 8, 'for': 9, 'was': 10, 'have': 11, 'of': 12, 'on': 13, 'this': 14, 'in': 15, 'but': 16, 'me': 17, 'had': 18, 'is': 19, 'that': 20, 'with': 21, 't': 22, 'not': 23, 'so': 24, 'been': 25, 'at': 26, 'after': 27, 'no': 28, 'day': 29, 'as': 30, 'am': 31, 'about': 32, 'm': 33, 'now': 34, 'side': 35, 'taking': 36, 'all': 37, 'has': 38, 've': 39, 's': 40, 'years': 41, 'pain': 42, 'effects': 43, 'first': 44, 'take': 45, 'you': 46, '2': 47, 'months': 48, 'only': 49, 'started': 50, 'like': 51, 'get': 52, 'up': 53, 'be': 54, 'days': 55, 'just': 56, 'very': 57, 'time': 58, 'or': 59, 'out': 60, 'from': 61, '3': 62, 'when': 63, 'feel': 64, 'can': 65, 'if': 66, 'would': 67, 'because': 68, 'back': 69, 'pill': 70, 'more': 71, 'one': 72, '\r': 73, 'weeks': 74, 'are': 75, 'week': 76, 'took': 77, 'doctor': 78, 'also': 79, 'period': 80, 'medication': 81, 'then': 82, 'before': 83, 'weight': 84, 'got': 85, 'did': 86, 'will': 87, 'month': 88, 'do': 89, 'which': 90, 'an': 91, 'life': 92, 'since': 93, 'don': 94, 'bad': 95, 'still': 96, 'off': 97, 'anxiety': 98, '5': 99, 'any': 100, 'really': 101, 'much': 102, 'some': 103, 'over': 104, 'never': 105, 'than': 106, 'better': 107, 'went': 108, '4': 109, 'medicine': 110, 'they': 111, 'work': 112, 'two': 113, 'quot': 114, 'other': 115, 'felt': 116, 'well': 117, 'control': 118, 'every': 119, 'good': 120, 'didn': 121, 'year': 122, 'even': 123, 'great': 124, 'night': 125, 'few': 126, '1': 127, 'go': 128, 'having': 129, 'sleep': 130, 'again': 131, 'ago': 132, 'by': 133, 'tried': 134, '6': 135, 'works': 136, 'were': 137, 'acne': 138, '10': 139, 'birth': 140, 'made': 141, 'drug': 142, 'depression': 143, 'little': 144, 'hours': 145, 'mg': 146, 'going': 147, 'last': 148, 'dose': 149, 'what': 150, 'prescribed': 151, 'worked': 152, 'used': 153, '\r\r': 154, 'could': 155, 'almost': 156, 'severe': 157, 'there': 158, 'down': 159, 'getting': 160, 'put': 161, 'help': 162, 'he': 163, 'your': 164, 'feeling': 165, 'use': 166, 'amp': 167, 'mood': 168, 'ever': 169, 'far': 170, 'nothing': 171, 'being': 172, 'skin': 173, 'nausea': 174, 'periods': 175, 'away': 176, 'sex': 177, 'stopped': 178, 'times': 179, 'lot': 180, 'try': 181, 'using': 182, 'symptoms': 183, 'cramps': 184, 'too': 185, 'bleeding': 186, 'think': 187, 'experience': 188, 'know': 189, 'lost': 190, 'normal': 191, 'helped': 192, 'gain': 193, 'long': 194, 'while': 195, 'recommend': 196, 'effect': 197, 'without': 198, 'worse': 199, 'old': 200, 'pills': 201, 'body': 202, 'its': 203, 'however': 204, 'them': 205, 'stop': 206, 'morning': 207, 'say': 208, '7': 209, 'until': 210, 'within': 211, 'most': 212, 'taken': 213, 'see': 214, 'once': 215, 'does': 216, 'thing': 217, 'always': 218, 'how': 219, 'many': 220, 'horrible': 221, 'next': 222, 'make': 223, 'through': 224, '8': 225, 'around': 226, 'due': 227, 'experienced': 228, 'she': 229, 'headaches': 230, 'these': 231, 'able': 232, 'haven': 233, 'noticed': 234, 'finally': 235, 'blood': 236, 'right': 237, 'stomach': 238, 'gone': 239, 'three': 240, 'later': 241, 'gave': 242, 'want': 243, 'myself': 244, 'love': 245, 'best': 246, 'different': 247, '20': 248, 'working': 249, 'eat': 250, 'sure': 251, 'same': 252, 'during': 253, 'thought': 254, 'pounds': 255, 'who': 256, 'though': 257, 'couldn': 258, 'less': 259, 'found': 260, 'we': 261, 'daily': 262, 'happy': 263, 'gained': 264, 'problems': 265, 'told': 266, 'people': 267, 'anything': 268, 'give': 269, 'said': 270, 'need': 271, '30': 272, 'second': 273, 'something': 274, 'swings': 275, 'way': 276, 'completely': 277, 'another': 278, 'things': 279, 'into': 280, 'couple': 281, 'face': 282, 'everything': 283, 'half': 284, 'start': 285, 'worst': 286, 'spotting': 287, 'drive': 288, 'panic': 289, 'worth': 290, 'tired': 291, 'new': 292, 'high': 293, 'starting': 294, 'bit': 295, 'may': 296, 'helps': 297, 'wasn': 298, 'terrible': 299, 'problem': 300, 'painful': 301, 'light': 302, 'dry': 303, 'relief': 304, 'dr': 305, 'loss':  ...

# %%
x_class.shape
# Out:
# (159523, 836)

# %%
# X_train, X_test, y_train, y_test = train_test_split(X,y_train, test_size = 0.05, random_state = 42)
# print(X_train.shape,y_train.shape)
# X_train
# print(X_test.shape,y_test.shape)

# %%
import keras
embed_dim = 500 #Change to observe effects
lstm_out = 256 #Change to observe effects
batch_size = 32


input1 = keras.layers.Input(shape=(200,))

input2 = keras.layers.Input(shape=(836,))
# xb = keras.layers.Dense(8, activation='relu')(input2)
# print(inputs.shape)
x = Embedding(num_words, embed_dim)(input1)    # More info on Embeddings here - https://machinelearningmastery.com/use-word-embedding-layers-deep-learning-keras/
# # And here : https://www.kaggle.com/rajmehra03/a-detailed-explanation-of-keras-embedding-layer
x = LSTM(lstm_out)(x) # The LSTM transforms the vector sequence into a single vector of size lstm_out, containing information about the entire sequence
# print(classes.shape)
xb=Dense(512,activation='relu', kernel_initializer='normal')(input2)

x = Dense(512,activation='relu', kernel_initializer='normal')(x)
added = keras.layers.Concatenate(axis=-1)([x,xb])
c=Dropout(0.2)(added)
c = Dense(512,activation='relu', kernel_initializer='normal')(c)
c=Dropout(0.2)(c)
# print(added.shape)
c = Dense(256,activation='relu', kernel_initializer='normal')(c)
c=Dropout(0.2)(added)
c = Dense(128,activation='relu', kernel_initializer='normal')(c)
c=Dropout(0.2)(added)
c = Dense(64,activation='relu', kernel_initializer='normal')(c)

c = Dense(1,activation='relu', kernel_initializer='normal')(c)
# X=keras.layers.Input(X)
# x_class=keras.layers.Input(x_class)
model = Model(inputs=[input1, input2], outputs=c)
print(model.summary())
import keras

# input1 = keras.layers.Input(shape=(16,))
# x1 = keras.layers.Dense(8, activation='relu')(input1)
# input2 = keras.layers.Input(shape=(32,))
# x2 = keras.layers.Dense(8, activation='relu')(input2)
# # equivalent to added = keras.layers.add([x1, x2])
# added = keras.layers.Add()([x1, x2])

# out = keras.layers.Dense(4)(added)
# model = keras.models.Model(inputs=[input1, input2], outputs=out)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4409: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 200, 500)     50000000    input_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 256)          775168      embedding_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 836)          0
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          131584      lstm_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          428544      input_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1024)         0           dense_2[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           65600       dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            65          dense_6[0][0]
# ==================================================================================================
# Total params: 51,400,961
# Trainable params: 51,400,961
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
import keras

# OPTIM=keras.optimizers.Adam(learning_rate=0.1, beta_1=0.999, beta_2=0.9999, amsgrad=False)
model.compile(loss = 'mean_squared_error', optimizer='adam',metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from keras.callbacks import ModelCheckpoint

filepath="weights-improvement.hdf5"

checkpoint = ModelCheckpoint(filepath, monitor='accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
model.fit(x=[X,x_class], y=y_train, batch_size=1024, epochs=30,callbacks=callbacks_list, verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/30
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 159523/159523 [==============================] - 201s 1ms/step - loss: 0.0939 - acc: 0.2873
# Epoch 2/30
# 159523/159523 [==============================] - 197s 1ms/step - loss: 0.0459 - acc: 0.3082
# Epoch 3/30
# 159523/159523 [==============================] - 195s 1ms/step - loss: 0.0371 - acc: 0.3110
# Epoch 4/30
# 159523/159523 [==============================] - 195s 1ms/step - loss: 0.0307 - acc: 0.3121
# Epoch 5/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0261 - acc: 0.3132
# Epoch 6/30
# 159523/159523 [==============================] - 195s 1ms/step - loss: 0.0223 - acc: 0.3140
# Epoch 7/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0196 - acc: 0.3144
# Epoch 8/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0171 - acc: 0.3148
# Epoch 9/30
# 159523/159523 [==============================] - 195s 1ms/step - loss: 0.0149 - acc: 0.3150
# Epoch 10/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0132 - acc: 0.3153
# Epoch 11/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0119 - acc: 0.3154
# Epoch 12/30
# 159523/159523 [==============================] - 195s 1ms/step - loss: 0.0107 - acc: 0.3156
# Epoch 13/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0099 - acc: 0.3156
# Epoch 14/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0084 - acc: 0.3158
# Epoch 15/30
# 159523/159523 [==============================] - 195s 1ms/step - loss: 0.0075 - acc: 0.3158
# Epoch 16/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0070 - acc: 0.3159
# Epoch 17/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0063 - acc: 0.3159
# Epoch 18/30
# 159523/159523 [==============================] - 195s 1ms/step - loss: 0.0056 - acc: 0.3160
# Epoch 19/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0058 - acc: 0.3160
# Epoch 20/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0057 - acc: 0.3160
# Epoch 21/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0049 - acc: 0.3160
# Epoch 22/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0042 - acc: 0.3160
# Epoch 23/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0038 - acc: 0.3160
# Epoch 24/30
# 159523/159523 [==============================] - 196s 1ms/step - loss: 0.0035 - acc: 0.3160
# Epoch 25/30
# 148480/159523 [==========================>...] - ETA: 13s - loss: 0.0032 - acc: 0.3156

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
Y=tokenizer.texts_to_sequences(test['desc'].values)
testing_input = pad_sequences(Y, maxlen=max_length_of_text)
testing_classes=[]
temp=np.array(test[['class']])
for i in temp:
    a=np.zeros(836)
    a[i]=1
    testing_classes.append(a)
testing_classes=np.array(testing_classes)

# %%
testing_classes.shape
# Out:
# (53175, 836)

# %%
filepath
# Out:
# 'weights-improvement.hdf5'

# %%
model.load_weights("weights-improvement.hdf5")

# %%
predict=model.predict([testing_input,testing_classes])

# %%
print(predict[0:50])
# Out:
# [[0.9551575 ]
#  [0.93129957]
#  [0.70015967]
#  [0.9939949 ]
#  [0.8049456 ]
#  [0.83168566]
#  [0.90468574]
#  [0.8964282 ]
#  [1.0063835 ]
#  [0.965646  ]
#  [0.11564302]
#  [0.82917094]
#  [0.66402555]
#  [0.4392736 ]
#  [0.7821231 ]
#  [0.11262063]
#  [0.26588106]
#  [0.7659465 ]
#  [0.68990636]
#  [0.09459773]
#  [0.8464795 ]
#  [0.1105778 ]
#  [0.93514854]
#  [0.7450979 ]
#  [0.12121028]
#  [0.9265176 ]
#  [0.9186396 ]
#  [0.10642537]
#  [0.9880592 ]
#  [0.77408046]
#  [0.1240554 ]
#  [0.9722923 ]
#  [0.99563324]
#  [0.9640954 ]
#  [0.8203163 ]
#  [0.1025921 ]
#  [1.0045614 ]
#  [0.7205233 ]
#  [0.12105299]
#  [0.7709186 ]
#  [0.12538971]
#  [0.99787617]
#  [0.99255633]
#  [0.6539326 ]
#  [0.70807844]
#  [0.56339747]
#  [0.12411694]
#  [0.838946  ]
#  [1.0848157 ]
#  [0.9248415 ]]

# %%
predictA=predict.reshape(-1)
predictB=predict.reshape(-1)

predictC=predict.reshape(-1)
predictD=predict.reshape(-1)

# %%
predictA=predictA/np.max(predictA)
predictA*=10
for i in range(53175):
    if predictA[i]>10:
        predictA[i]=10.0
    elif predictA[i]<1:
        predictA[i]=1.0
    else:
        pass
y_test=np.ceil(predictA)
y_test.reshape(53175)
import csv
sub=open("sub1.csv","w")
writer=csv.writer(sub)
writer.writerow(["Id","rating"])
for i in range(0,53175):
    writer.writerow([i,y_test[i]])
sub.close()

# %% [markdown]
# <a href="sub1.csv">subA</a>

# %% [markdown]
# * <a href="weights-improvement.hdf5">download</a>

# %%
# predictB=predictB
predictB*=10
for i in range(53175):
    if predictB[i]>10:
        predictB[i]=10.0
    elif predictB[i]<1:
        predictB[i]=1.0
    else:
        pass
y_test=np.ceil(predictB)
y_test.reshape(53175)
import csv
sub=open("sub2.csv","w")
writer=csv.writer(sub)
writer.writerow(["Id","rating"])
for i in range(0,53175):
    writer.writerow([i,y_test[i]])
sub.close()

# %% [markdown]
# <a href="sub2.csv">subB</a>

# %%
predictC=predictC/np.max(predictC)
predictC*=10
predictC=np.floor(predictC)
for i in range(53175):
    if predictC[i]>10:
        predictC[i]=10.0
    elif predictC[i]<1:
        predictC[i]=1.0
    else:
        pass
# y_test=np.ceil(predictB)
y_test=y_test.reshape(-1)
import csv
sub=open("sub3.csv","w")
writer=csv.writer(sub)
writer.writerow(["Id","rating"])
for i in range(0,53175):
    writer.writerow([i,y_test[i]])
sub.close()

# %% [markdown]
# <a href="sub3.csv">subC</a>

# %%
print('done')
# Out:
# done
